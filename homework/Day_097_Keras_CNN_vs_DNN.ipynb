# %%
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
import os
# Out:
# Using TensorFlow backend.

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 10 # 訓練的 epochs 數量

# 讀取資料並檢視
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# 對 label 進行 one-hot encoding (y_trian 原本是純數字)
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## 首先我們使用一般的 DNN (MLP) 來訓練
# 由於 DNN 只能輸入一維的資料，我們要先將影像進行攤平，若 (50000, 32, 32, 3) 的影像，攤平後會變成 (50000, 32*32*3) = (50000, 3072)

# %%
# 將資料攤平成一維資料
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

# 將資料變為 float32 並標準化
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 9s 187us/step - loss: 2.1389 - accuracy: 0.2515 - val_loss: 1.8387 - val_accuracy: 0.3387
# Epoch 2/10
# 50000/50000 [==============================] - 10s 202us/step - loss: 1.8564 - accuracy: 0.3301 - val_loss: 1.8240 - val_accuracy: 0.3443
# Epoch 3/10
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.7844 - accuracy: 0.3583 - val_loss: 1.6775 - val_accuracy: 0.4062
# Epoch 4/10
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.7361 - accuracy: 0.3740 - val_loss: 1.6639 - val_accuracy: 0.4084
# Epoch 5/10
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.6978 - accuracy: 0.3895 - val_loss: 1.6614 - val_accuracy: 0.4055
# Epoch 6/10
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.6760 - accuracy: 0.4003 - val_loss: 1.6240 - val_accuracy: 0.4096
# Epoch 7/10
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.6538 - accuracy: 0.4071 - val_loss: 1.5517 - val_accuracy: 0.4500
# Epoch 8/10
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.6266 - accuracy: 0.4179 - val_loss: 1.5826 - val_accuracy: 0.4481
# Epoch 9/10
# 50000/50000 [==============================] - 11s 211us/step - loss: 1.6168 - accuracy: 0.4207 - val_loss: 1.5943 - val_accuracy: 0.4250
# Epoch 10/10
# 50000/50000 [==============================] - 9s 186us/step - loss: 1.6047 - accuracy: 0.4251 - val_loss: 1.5901 - val_accuracy: 0.4349
# Test loss: 1.5900518928527831
# Test accuracy: 0.4348999857902527

# %% [markdown]
# ## 接下來我們使用 CNN 來訓練神經網路
# CNN 的原理非常適合處理影像類的資料，就讓我們來看看，同樣的訓練條件，CNN 是否顯著優於 DNN 呢?

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_10 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# activation_11 (Activation)   (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               819712
# _________________________________________________________________
# activation_12 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_13 (Activation)   (None, 10)                0
# =================================================================
# Total params: 927,338
# Trainable params: 927,338
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 104s 2ms/step - loss: 1.8074 - accuracy: 0.3428 - val_loss: 1.4559 - val_accuracy: 0.4685
# Epoch 2/10
# 50000/50000 [==============================] - 109s 2ms/step - loss: 1.4041 - accuracy: 0.4958 - val_loss: 1.1910 - val_accuracy: 0.5748
# Epoch 3/10
# 50000/50000 [==============================] - 109s 2ms/step - loss: 1.2030 - accuracy: 0.5749 - val_loss: 1.3408 - val_accuracy: 0.5345
# Epoch 4/10
# 50000/50000 [==============================] - 112s 2ms/step - loss: 1.0686 - accuracy: 0.6240 - val_loss: 0.9936 - val_accuracy: 0.6560
# Epoch 5/10
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.9652 - accuracy: 0.6647 - val_loss: 0.8689 - val_accuracy: 0.6977
# Epoch 6/10
# 50000/50000 [==============================] - 112s 2ms/step - loss: 0.8834 - accuracy: 0.6942 - val_loss: 0.8134 - val_accuracy: 0.7124
# Epoch 7/10
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.8238 - accuracy: 0.7128 - val_loss: 0.9387 - val_accuracy: 0.6836
# Epoch 8/10
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.7727 - accuracy: 0.7314 - val_loss: 0.7444 - val_accuracy: 0.7450
# Epoch 9/10
# 50000/50000 [==============================] - 110s 2ms/step - loss: 0.7343 - accuracy: 0.7461 - val_loss: 0.7407 - val_accuracy: 0.7509
# Epoch 10/10
# 50000/50000 [==============================] - 109s 2ms/step - loss: 0.6950 - accuracy: 0.7603 - val_loss: 0.7108 - val_accuracy: 0.7559
# Test loss: 0.7108313632011414
# Test accuracy: 0.7559000253677368

# %%
batch_size = 128 # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 50 # 訓練的 epochs 數量

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_20 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_21 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_22 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_23 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               1180160
# _________________________________________________________________
# activation_24 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_25 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 1.7244 - accuracy: 0.3748 - val_loss: 1.3517 - val_accuracy: 0.5079
# Epoch 2/50
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3103 - accuracy: 0.5330 - val_loss: 1.1412 - val_accuracy: 0.5997
# Epoch 3/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 1.1096 - accuracy: 0.6105 - val_loss: 0.9721 - val_accuracy: 0.6652
# Epoch 4/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.9838 - accuracy: 0.6579 - val_loss: 0.8649 - val_accuracy: 0.6985
# Epoch 5/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.8874 - accuracy: 0.6930 - val_loss: 0.8996 - val_accuracy: 0.6891
# Epoch 6/50
# 50000/50000 [==============================] - 91s 2ms/step - loss: 0.8202 - accuracy: 0.7158 - val_loss: 0.7808 - val_accuracy: 0.7316
# Epoch 7/50
# 50000/50000 [==============================] - 98s 2ms/step - loss: 0.7676 - accuracy: 0.7344 - val_loss: 0.7129 - val_accuracy: 0.7562
# Epoch 8/50
# 50000/50000 [==============================] - 98s 2ms/step - loss: 0.7158 - accuracy: 0.7517 - val_loss: 0.8661 - val_accuracy: 0.6986
# Epoch 9/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.6871 - accuracy: 0.7636 - val_loss: 0.6662 - val_accuracy: 0.7739
# Epoch 10/50
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.6622 - accuracy: 0.7705 - val_loss: 0.6877 - val_accuracy: 0.7671
# Epoch 11/50
# 50000/50000 [==============================] - 101s 2ms/step - loss: 0.6409 - accuracy: 0.7806 - val_loss: 0.7107 - val_accuracy: 0.7652
# Epoch 12/50
# 50000/50000 [==============================] - 99s 2ms/step - loss: 0.6189 - accuracy: 0.7863 - val_loss: 0.6791 - val_accuracy: 0.7803
# Epoch 13/50
# 50000/50000 [==============================] - 99s 2ms/step - loss: 0.6089 - accuracy: 0.7930 - val_loss: 0.7134 - val_accuracy: 0.7608
# Epoch 14/50
# 50000/50000 [==============================] - 98s 2ms/step - loss: 0.6040 - accuracy: 0.7950 - val_loss: 0.6647 - val_accuracy: 0.7826
# Epoch 15/50
# 50000/50000 [==============================] - 98s 2ms/step - loss: 0.6028 - accuracy: 0.7958 - val_loss: 0.6383 - val_accuracy: 0.7913
# Epoch 16/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.5869 - accuracy: 0.8007 - val_loss: 0.6934 - val_accuracy: 0.7895
# Epoch 17/50
# 50000/50000 [==============================] - 91s 2ms/step - loss: 0.5896 - accuracy: 0.8026 - val_loss: 0.6781 - val_accuracy: 0.7722
# Epoch 18/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5907 - accuracy: 0.8022 - val_loss: 0.6679 - val_accuracy: 0.7943
# Epoch 19/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5854 - accuracy: 0.8058 - val_loss: 0.6476 - val_accuracy: 0.7881
# Epoch 20/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.5867 - accuracy: 0.8064 - val_loss: 0.6608 - val_accuracy: 0.7833
# Epoch 21/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5920 - accuracy: 0.8038 - val_loss: 0.7020 - val_accuracy: 0.7749
# Epoch 22/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.5892 - accuracy: 0.8069 - val_loss: 0.6952 - val_accuracy: 0.7787
# Epoch 23/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.5857 - accuracy: 0.8069 - val_loss: 0.6540 - val_accuracy: 0.7897
# Epoch 24/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.5907 - accuracy: 0.8075 - val_loss: 0.7298 - val_accuracy: 0.7760
# Epoch 25/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.5868 - accuracy: 0.8074 - val_loss: 0.6797 - val_accuracy: 0.7779
# Epoch 26/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 0.5890 - accuracy: 0.8071 - val_loss: 0.7350 - val_accuracy: 0.7812
# Epoch 27/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.5911 - accuracy: 0.8094 - val_loss: 0.7057 - val_accuracy: 0.7890
# Epoch 28/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.5919 - accuracy: 0.8083 - val_loss: 0.6792 - val_accuracy: 0.7929
# Epoch 29/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.5975 - accuracy: 0.8070 - val_loss: 0.6331 - val_accuracy: 0.8019
# Epoch 30/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.5989 - accuracy: 0.8072 - val_loss: 0.6972 - val_accuracy: 0.7861
# Epoch 31/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6031 - accuracy: 0.8065 - val_loss: 0.6487 - val_accuracy: 0.7983
# Epoch 32/50
# 50000/50000 [==============================] - 99s 2ms/step - loss: 0.5966 - accuracy: 0.8081 - val_loss: 0.7364 - val_accuracy: 0.7855
# Epoch 33/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.5993 - accuracy: 0.8081 - val_loss: 0.7132 - val_accuracy: 0.7737
# Epoch 34/50
# 50000/50000 [==============================] - 92s 2ms/step - loss: 0.5997 - accuracy: 0.8052 - val_loss: 0.7883 - val_accuracy: 0.7744
# Epoch 35/50
# 50000/50000 [==============================] - 93s 2ms/step - loss: 0.6039 - accuracy: 0.8065 - val_loss: 0.8516 - val_accuracy: 0.7363
# Epoch 36/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.6151 - accuracy: 0.8032 - val_loss: 0.7417 - val_accuracy: 0.7644
# Epoch 37/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.6181 - accuracy: 0.8018 - val_loss: 0.6248 - val_accuracy: 0.8015
# Epoch 38/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.6122 - accuracy: 0.8036 - val_loss: 0.6830 - val_accuracy: 0.7808
# Epoch 39/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.6190 - accuracy: 0.8012 - val_loss: 0.7225 - val_accuracy: 0.7769
# Epoch 40/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.6306 - accuracy: 0.8003 - val_loss: 0.6817 - val_accuracy: 0.7987
# Epoch 41/50
# 50000/50000 [==============================] - 95s 2ms/step - loss: 0.6261 - accuracy: 0.7992 - val_loss: 0.8107 - val_accuracy: 0.7894
# Epoch 42/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.6264 - accuracy: 0.8004 - val_loss: 0.6740 - val_accuracy: 0.7881
# Epoch 43/50
# 50000/50000 [==============================] - 96s 2ms/step - loss: 0.6385 - accuracy: 0.7958 - val_loss: 0.7184 - val_accuracy: 0.7727
# Epoch 44/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.6389 - accuracy: 0.7956 - val_loss: 0.6912 - val_accuracy: 0.7754
# Epoch 45/50
# 50000/50000 [==============================] - 97s 2ms/step - loss: 0.6480 - accuracy: 0.7934 - val_loss: 0.7917 - val_accuracy: 0.7524
# Epoch 46/50
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.6511 - accuracy: 0.7950 - val_loss: 0.6685 - val_accuracy: 0.7823
# Epoch 47/50
# 50000/50000 [==============================] - 102s 2ms/step - loss: 0.6505 - accuracy: 0.7950 - val_loss: 0.7096 - val_accuracy: 0.7800
# Epoch 48/50
# 50000/50000 [==============================] - 104s 2ms/step - loss: 0.6608 - accuracy: 0.7905 - val_loss: 0.7045 - val_accuracy: 0.7718
# Epoch 49/50
# 50000/50000 [==============================] - 100s 2ms/step - loss: 0.6621 - accuracy: 0.7913 - val_loss: 0.7836 - val_accuracy: 0.7749
# Epoch 50/50
# 50000/50000 [==============================] - 100s 2ms/step - loss: 0.6602 - accuracy: 0.7891 - val_loss: 0.7619 - val_accuracy: 0.7625
# Test loss: 0.7619074200630188
# Test accuracy: 0.762499988079071

# %% [markdown]
# ## 同樣運算 10 個 epochs，但 CNN 在 test data 的準確率顯著優於 DNN!

# %% [markdown]
# ## 作業
# 1. 請試著調整各個超參數，並說明那些超參數對於結果有明顯的影響?
#
#     網路層數 epoch batch_size
# 2. CNN 與 DNN 哪個模型的參數數量比較多? 造成參數的數量不同的原因在哪?
#
#     DNN有主要組成為FC層, 參數公式為(輸入大小+1)*神經元數 CNN
